# %%
import numpy as np
import xarray as xr

from experiment.filesystem.zarr_store import ZarrStore
from experiment.evaluation.visualization import _plot_errors, _plot_differences, _plot_kinematics

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
root_path = "data/results/mediterranea"
experiment_datetime = "2024-04-02/13-22-57"
experiment_path = f"{root_path}/{experiment_datetime}/"

# %%
scc_fields_zstore = ZarrStore(experiment_path, "ssc_fields.zarr")
scc_fields_ds = xr.open_zarr(scc_fields_zstore.store)
scc_fields_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                        (latitude: 59, longitude: 169)
# Coordinates:
#   * latitude                                       (latitude) float32 30.12 ....
#   * longitude                                      (longitude) float32 -5.625...
# Data variables: (12/56)
#     adt                                            (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     eke_avg_DUACS                                  (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     eke_avg_Geostrophy                             (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     eke_avg_Iterative                              (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     eke_avg_Iterative_filter                       (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     eke_avg_Variational                            (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     ...                                             ...
#     magn_avg_Variational                           (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     nrv_avg_DUACS                                  (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     nrv_avg_Geostrophy                             (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     nrv_avg_Iterative                              (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     nrv_avg_Iterative_filter                       (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>
#     nrv_avg_Variational                            (latitude, longitude) float64 dask.array<chunksize=(59, 169), meta=np.ndarray>

# %%
data_vars = [var for var in scc_fields_ds.variables if "DUACS" not in var]

# %%
ssc_fields_hl_ds = scc_fields_ds.where(np.abs(scc_fields_ds.latitude) > 5)

# %%
_plot_kinematics(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 17:46:59 - WARNING - list index out of range
# 2024-04-06 17:46:59 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:00 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:00 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:00 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:00 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:01 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_errors(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:02 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_differences(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:03 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:04 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:04 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:04 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:04 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:04 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:47:04 - WARNING - 'NoneType' object has no attribute 'open'

# %%
ssc_fields_hl_ds.mean(["latitude", "longitude"]).compute()
# Out:
# <xarray.Dataset>
# Dimensions:                                        ()
# Data variables: (12/56)
#     adt                                            float64 0.01052
#     eke_avg_DUACS                                  float64 0.007871
#     eke_avg_Geostrophy                             float64 0.006773
#     eke_avg_Iterative                              float64 0.006918
#     eke_avg_Iterative_filter                       float64 0.006915
#     eke_avg_Variational                            float64 0.006931
#     ...                                             ...
#     magn_avg_Variational                           float64 0.09433
#     nrv_avg_DUACS                                  float64 0.0006924
#     nrv_avg_Geostrophy                             float64 0.001334
#     nrv_avg_Iterative                              float64 0.001335
#     nrv_avg_Iterative_filter                       float64 0.001335
#     nrv_avg_Variational                            float64 0.001344
