# %%
import numpy as np
import xarray as xr

from experiment.filesystem.zarr_store import ZarrStore
from experiment.evaluation.visualization import _plot_errors, _plot_differences, _plot_kinematics

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
root_path = "data/results/alboran"
experiment_datetime = "2024-04-02/12-36-20"
experiment_path = f"{root_path}/{experiment_datetime}/"

# %%
scc_fields_zstore = ZarrStore(experiment_path, "ssc_fields.zarr")
scc_fields_ds = xr.open_zarr(scc_fields_zstore.store)
scc_fields_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                        (latitude: 11, longitude: 20)
# Coordinates:
#   * latitude                                       (latitude) float32 34.62 ....
#   * longitude                                      (longitude) float32 -5.625...
# Data variables: (12/56)
#     adt                                            (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     eke_avg_DUACS                                  (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     eke_avg_Geostrophy                             (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     eke_avg_Iterative                              (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     eke_avg_Iterative_filter                       (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     eke_avg_Variational                            (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     ...                                             ...
#     magn_avg_Variational                           (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     nrv_avg_DUACS                                  (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     nrv_avg_Geostrophy                             (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     nrv_avg_Iterative                              (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     nrv_avg_Iterative_filter                       (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>
#     nrv_avg_Variational                            (latitude, longitude) float64 dask.array<chunksize=(11, 20), meta=np.ndarray>

# %%
data_vars = [var for var in scc_fields_ds.variables if "DUACS" not in var]

# %%
ssc_fields_hl_ds = scc_fields_ds.where(np.abs(scc_fields_ds.latitude) > 5)

# %%
_plot_kinematics(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 17:45:54 - WARNING - list index out of range
# 2024-04-06 17:45:54 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:55 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:56 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:56 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:56 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:56 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:45:56 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_errors(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 17:46:07 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:07 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:07 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:07 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_differences(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 17:46:10 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:10 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:10 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:10 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 17:46:11 - WARNING - 'NoneType' object has no attribute 'open'

# %%
ssc_fields_hl_ds.mean(["latitude", "longitude"]).compute()
# Out:
# <xarray.Dataset>
# Dimensions:                                        ()
# Data variables: (12/56)
#     adt                                            float64 0.07876
#     eke_avg_DUACS                                  float64 0.02524
#     eke_avg_Geostrophy                             float64 0.02007
#     eke_avg_Iterative                              float64 0.02157
#     eke_avg_Iterative_filter                       float64 0.02155
#     eke_avg_Variational                            float64 0.02165
#     ...                                             ...
#     magn_avg_Variational                           float64 0.173
#     nrv_avg_DUACS                                  float64 0.00155
#     nrv_avg_Geostrophy                             float64 0.00206
#     nrv_avg_Iterative                              float64 0.002104
#     nrv_avg_Iterative_filter                       float64 0.0021
#     nrv_avg_Variational                            float64 0.002335
