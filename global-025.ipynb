# %%
import numpy as np
import xarray as xr

from experiment.filesystem.zarr_store import ZarrStore
from experiment.evaluation.visualization import _plot_errors, _plot_differences, _plot_kinematics

# %load_ext autoreload
# %autoreload 2

# %%
root_path = "data/results/global"
experiment_datetime = "2024-04-11/06-44-57"
experiment_path = f"{root_path}/{experiment_datetime}/"

# %%
ssc_fields_zstore = ZarrStore(experiment_path, "ssc_fields.zarr")
ssc_fields_ds = xr.open_zarr(ssc_fields_zstore.store)
ssc_fields_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                    (latitude: 675, longitude: 1440)
# Coordinates:
#   * latitude                                   (latitude) float32 -78.62 ... ...
#   * longitude                                  (longitude) float32 -179.9 ......
# Data variables: (12/48)
#     eke_avg_DUACS                              (latitude, longitude) float64 dask.array<chunksize=(169, 360), meta=np.ndarray>
#     eke_avg_Geostrophy                         (latitude, longitude) float64 dask.array<chunksize=(169, 360), meta=np.ndarray>
#     eke_avg_Variational                        (latitude, longitude) float64 dask.array<chunksize=(169, 360), meta=np.ndarray>
#     eke_avg_diff_Geostrophy_DUACS              (latitude, longitude) float64 dask.array<chunksize=(169, 360), meta=np.ndarray>
#     eke_avg_diff_Variational_DUACS             (latitude, longitude) float64 dask.array<chunksize=(169, 360), meta=np.ndarray>
# ...

# %%
data_vars = [var for var in ssc_fields_ds.variables if "DUACS" not in var]

# %%
ssc_fields_hl_ds = ssc_fields_ds.where(np.abs(ssc_fields_ds.latitude) > 5)

# %%
_plot_kinematics(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-12 09:11:19 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:20 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:20 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:20 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:21 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:21 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:22 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:22 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:22 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:23 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:23 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:23 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:24 - WARNING - 'NoneType' object has no attribute 'open'
# ...

# %%
_plot_errors(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-12 09:11:25 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:26 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:26 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:27 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:27 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:27 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_differences(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-12 09:11:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:29 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:29 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:30 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:30 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:31 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-12 09:11:31 - WARNING - 'NoneType' object has no attribute 'open'

# %%
ssc_fields_hl_ds.mean(["latitude", "longitude"]).compute()
# Out:
# <xarray.Dataset>
# Dimensions:                                    ()
# Data variables: (12/48)
#     eke_avg_DUACS                              float64 0.0148
#     eke_avg_Geostrophy                         float64 0.01335
#     eke_avg_Variational                        float64 0.01392
#     eke_avg_diff_Geostrophy_DUACS              float64 -0.001456
#     eke_avg_diff_Variational_DUACS             float64 -0.0008783
#     eke_avg_diff_Variational_Geostrophy        float64 0.0005781
#     ...                                         ...
#     u_avg_DUACS                                float64 0.0168
#     u_avg_Geostrophy                           float64 0.01727
#     u_avg_Variational                          float64 0.01728
#     v_avg_DUACS                                float64 0.0008124
#     v_avg_Geostrophy                           float64 0.001087
#     v_avg_Variational                          float64 0.001087
