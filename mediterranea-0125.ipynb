# %%
import numpy as np
import xarray as xr

from experiment.filesystem.zarr_store import ZarrStore
from experiment.evaluation.visualization import _plot_errors, _plot_differences, _plot_kinematics

# %load_ext autoreload
# %autoreload 2

# %%
root_path = "data/results/mediterranea"
experiment_datetime = "2024-04-06/17-52-06"
experiment_path = f"{root_path}/{experiment_datetime}/"

# %%
scc_fields_zstore = ZarrStore(experiment_path, "ssc_fields.zarr")
scc_fields_ds = xr.open_zarr(scc_fields_zstore.store)
scc_fields_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                    (latitude: 119, longitude: 339)
# Coordinates:
#   * latitude                                   (latitude) float32 30.06 ... 4...
#   * longitude                                  (longitude) float32 -5.688 ......
# Data variables: (12/48)
#     eke_avg_DUACS                              (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     eke_avg_Geostrophy                         (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     eke_avg_Variational                        (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     eke_avg_diff_Geostrophy_DUACS              (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     eke_avg_diff_Variational_DUACS             (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     eke_avg_diff_Variational_Geostrophy        (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     ...                                         ...
#     u_avg_DUACS                                (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     u_avg_Geostrophy                           (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     u_avg_Variational                          (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     v_avg_DUACS                                (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     v_avg_Geostrophy                           (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>
#     v_avg_Variational                          (latitude, longitude) float64 dask.array<chunksize=(60, 339), meta=np.ndarray>

# %%
data_vars = [var for var in scc_fields_ds.variables if "DUACS" not in var]

# %%
ssc_fields_hl_ds = scc_fields_ds.where(np.abs(scc_fields_ds.latitude) > 5)

# %%
_plot_kinematics(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 18:46:25 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:26 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:26 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:27 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:27 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:27 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:28 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:29 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:29 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:29 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:29 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:29 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_errors(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 18:46:30 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:30 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:30 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:31 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:31 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:31 - WARNING - 'NoneType' object has no attribute 'open'

# %%
_plot_differences(ssc_fields_hl_ds[data_vars], None, f"{experiment_path}/plots", quantile=.999)
# Out:
# 2024-04-06 18:46:32 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:32 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:32 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:33 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:33 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:34 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:34 - WARNING - 'NoneType' object has no attribute 'open'
# 2024-04-06 18:46:34 - WARNING - 'NoneType' object has no attribute 'open'

# %%
ssc_fields_hl_ds.mean(["latitude", "longitude"]).compute()
# Out:
# <xarray.Dataset>
# Dimensions:                                    ()
# Data variables: (12/48)
#     eke_avg_DUACS                              float64 0.007133
#     eke_avg_Geostrophy                         float64 0.006853
#     eke_avg_Variational                        float64 0.007156
#     eke_avg_diff_Geostrophy_DUACS              float64 -0.0002802
#     eke_avg_diff_Variational_DUACS             float64 2.31e-05
#     eke_avg_diff_Variational_Geostrophy        float64 0.0003033
#     ...                                         ...
#     u_avg_DUACS                                float64 0.01291
#     u_avg_Geostrophy                           float64 0.01422
#     u_avg_Variational                          float64 0.01425
#     v_avg_DUACS                                float64 -0.005793
#     v_avg_Geostrophy                           float64 -0.004188
#     v_avg_Variational                          float64 -0.004203
